# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.graph_objs as go
from plotly import tools
from numpy.fft import fft, ifft
from scipy.signal import find_peaks
from scipy import signal
from scipy.signal import argrelextrema
py.init_notebook_mode(connected=True)
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
#from catboost import CatBoostClassifier
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('/content/drive/MyDrive/PCOMP/dataSetPCOMP.csv')
df
# Out:
#           f_60         f_120         f_180     f_240         f_300     f_360  \
# 0     0.050333  0.000000e+00  1.467614e-02  0.000000  1.299852e-02  0.003011
# 1     0.042935  0.000000e+00  2.071503e-02  0.000000  1.702037e-02  0.000000
# 2     0.041060  0.000000e+00  2.170987e-02  0.003339  1.414790e-02  0.002724
# 3     0.045386  0.000000e+00  1.424042e-02  0.000000  1.694164e-02  0.003260
# 4     0.050650  0.000000e+00  1.481876e-02  0.003330  1.355751e-02  0.000000
# ...        ...           ...           ...       ...           ...       ...
# 1995  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1996  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1997  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1998  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1999  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
#
#              f_420     f_480     f_540         f_600  ...         f_720  \
# 0     6.827211e-03  0.001199  0.000489  1.158067e-03  ...  7.661253e-04
# 1     6.085138e-03  0.001350  0.001674  2.207066e-03  ...  0.000000e+00
# 2     9.262166e-03  0.003693  0.001803  0.000000e+00  ...  1.725142e-03
# 3     8.512001e-03  0.002953  0.002747  2.879539e-03  ...  1.341716e-03
# 4     6.695595e-03  0.001534  0.000000  6.317654e-04  ...  8.131323e-04
# ...            ...       ...       ...           ...  ...           ...
# 1995  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1996  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1997  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1998  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1999  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
#
#              f_780     f_840         f_900     f_960    f_1020        f_1080  \
# 0     2.804903e-03  0.000000  1.115797e-03  0.000541  0.001074  4.129106e-04
# 1     3.827063e-03  0.000757  1.827950e-03  0.000924  0.002003  1.353241e-03
# 2     2.196979e-03  0.001957  8.566290e-04  0.001364  0.001421  0.000000e+00
# 3     2.725649e-03  0.000000  1.712378e-03  0.001216  0.001194  8.769052e-04
# 4     2.994829e-03  0.000000  1.151151e-03  0.000000  0.001070  0.000000e+00
# ...            ...       ...           ...       ...       ...           ...
# 1995  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1996  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1997  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1998  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1999  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
#
#         f_1140        f_1200     device
# 0     0.000979  7.242021e-04  microwave
# 1     0.000000  1.370588e-03  microwave
# 2     0.001726  0.000000e+00  microwave
# 3     0.001102  1.548668e-03  microwave
# 4     0.001244  7.511724e-04  microwave
# ...        ...           ...        ...
# 1995  0.000000  5.289863e-19        fan
# 1996  0.000000  5.289863e-19        fan
# 1997  0.000000  5.289863e-19        fan
# 1998  0.000000  5.289863e-19        fan
# 1999  0.000000  5.289863e-19        fan
#
# [2000 rows x 21 columns]

# %%
classes = ["microwave", "airConditioner", "refrigerator", "monitor", "fan"]
X = df.drop(columns=['device'])
y = df['device'].apply(classes.index).to_numpy()
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)

# %% [markdown]
# ## Random Forest

# %%
GRID = [
    {
        'scaler': [StandardScaler()],
        'estimator': [RandomForestClassifier(random_state=42)],
        'estimator__n_estimators': [50, 100, 200],        # Número de árvores na floresta
        'estimator__max_depth': [None, 10, 20, 30],      # Profundidade máxima das árvores
        'estimator__min_samples_split': [2, 5, 10],      # Número mínimo de amostras necessárias para dividir um nó
        'estimator__min_samples_leaf': [1, 2, 4]         # Número mínimo de amostras necessárias para ser uma folha
    }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', RandomForestClassifier())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.7s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   1.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.7s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.7s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   1.8s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   1.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   1.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.8s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.8s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.8s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# ...
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.4s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.5s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.8s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   1.0s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.8s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.7s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=50, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=100, scaler=StandardScaler(); total time=   0.3s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.6s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# [CV] END estimator=RandomForestClassifier(random_state=42), estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, estimator__n_estimators=200, scaler=StandardScaler(); total time=   0.9s
# Melhor F1-SCORE:  0.9337256769228413

# %%
best_model.best_params_
# Out:
# {'estimator': RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                         n_estimators=50, random_state=42),
#  'estimator__max_depth': 10,
#  'estimator__min_samples_leaf': 2,
#  'estimator__min_samples_split': 5,
#  'estimator__n_estimators': 50,
#  'scaler': StandardScaler()}

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.9428507055040726
# Acurácia:  0.94375

# %% [markdown]
# ## Gradient Boosting

# %%
GRID = [
    {
        'scaler': [StandardScaler()],
        'estimator': [GradientBoostingClassifier(random_state=42)],
        'estimator__n_estimators': [50, 100, 200],        # Número de estimadores (árvores)
        'estimator__learning_rate': [0.01, 0.1, 0.2],    # Taxa de aprendizado
        'estimator__max_depth': [3, 4, 5],               # Profundidade máxima das árvores de decisão
        'estimator__min_samples_split': [2, 3, 4]        # Número mínimo de amostras necessárias para dividir um nó
     }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', GradientBoostingClassifier())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 81 candidates, totalling 810 fits
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.8s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   6.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.8s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   5.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   3.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   3.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   3.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   6.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   5.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   2.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=3, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.8s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   7.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   1.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=4, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   3.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   5.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   5.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   5.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=  11.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   8.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   9.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.01, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# ...
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   6.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=2, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   3.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   5.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=3, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.1s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.7s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.0s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=50, scaler=StandardScaler(); total time=   2.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.8s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.2s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   4.8s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=100, scaler=StandardScaler(); total time=   3.3s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.4s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.9s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   5.6s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.8s
# [CV] END estimator=GradientBoostingClassifier(random_state=42), estimator__learning_rate=0.2, estimator__max_depth=5, estimator__min_samples_split=4, estimator__n_estimators=200, scaler=StandardScaler(); total time=   4.5s
# Melhor F1-SCORE:  0.94030756472533

# %%
best_model.best_params_
# Out:
# {'estimator': GradientBoostingClassifier(learning_rate=0.2, max_depth=4, random_state=42),
#  'estimator__learning_rate': 0.2,
#  'estimator__max_depth': 4,
#  'estimator__min_samples_split': 2,
#  'estimator__n_estimators': 100,
#  'scaler': StandardScaler()}

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.9432026551677485
# Acurácia:  0.94375

# %% [markdown]
# ## Decision Tree

# %%
GRID = [
    {
        'scaler': [StandardScaler()],
        'estimator': [DecisionTreeClassifier(random_state=42)],
        'estimator__criterion': ['gini', 'entropy'],    # Critério de divisão
        'estimator__max_depth': [None, 10, 20, 30],     # Profundidade máxima da árvore
        'estimator__min_samples_split': [2, 5, 10],    # Número mínimo de amostras para dividir um nó
        'estimator__min_samples_leaf': [1, 2, 4]       # Número mínimo de amostras em um nó folha

     }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', DecisionTreeClassifier())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=None, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=10, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=gini, estimator__max_depth=20, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# ...
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=1, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=2, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=5, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=DecisionTreeClassifier(random_state=42), estimator__criterion=entropy, estimator__max_depth=30, estimator__min_samples_leaf=4, estimator__min_samples_split=10, scaler=StandardScaler(); total time=   0.0s
# Melhor F1-SCORE:  0.9255501932500954

# %%
best_model.best_params_
# Out:
# {'estimator': DecisionTreeClassifier(random_state=42),
#  'estimator__criterion': 'gini',
#  'estimator__max_depth': None,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'scaler': StandardScaler()}

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.9249295966819538
# Acurácia:  0.92625
