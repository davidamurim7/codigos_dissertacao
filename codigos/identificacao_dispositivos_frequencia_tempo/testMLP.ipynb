# %%
# !pip install sklearn-deap
# Out:
# Requirement already satisfied: sklearn-deap in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from sklearn-deap) (1.23.5)
# Requirement already satisfied: scipy>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-deap) (1.11.2)
# Requirement already satisfied: deap>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from sklearn-deap) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-deap) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->sklearn-deap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.0->sklearn-deap) (3.2.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.graph_objs as go
from plotly import tools
from numpy.fft import fft, ifft
from scipy.signal import find_peaks
from scipy import signal
from scipy.signal import argrelextrema
py.init_notebook_mode(connected=True)
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
#from catboost import CatBoostClassifier
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('/content/drive/MyDrive/PCOMP/dataSetPCOMP.csv')
df
# Out:
#           f_60         f_120         f_180     f_240         f_300     f_360  \
# 0     0.050333  0.000000e+00  1.467614e-02  0.000000  1.299852e-02  0.003011
# 1     0.042935  0.000000e+00  2.071503e-02  0.000000  1.702037e-02  0.000000
# 2     0.041060  0.000000e+00  2.170987e-02  0.003339  1.414790e-02  0.002724
# 3     0.045386  0.000000e+00  1.424042e-02  0.000000  1.694164e-02  0.003260
# 4     0.050650  0.000000e+00  1.481876e-02  0.003330  1.355751e-02  0.000000
# ...        ...           ...           ...       ...           ...       ...
# 1995  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1996  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1997  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1998  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
# 1999  0.000000  5.206701e-18  2.122895e-18  0.000000  1.434141e-18  0.000000
#
#              f_420     f_480     f_540         f_600  ...         f_720  \
# 0     6.827211e-03  0.001199  0.000489  1.158067e-03  ...  7.661253e-04
# 1     6.085138e-03  0.001350  0.001674  2.207066e-03  ...  0.000000e+00
# 2     9.262166e-03  0.003693  0.001803  0.000000e+00  ...  1.725142e-03
# 3     8.512001e-03  0.002953  0.002747  2.879539e-03  ...  1.341716e-03
# 4     6.695595e-03  0.001534  0.000000  6.317654e-04  ...  8.131323e-04
# ...            ...       ...       ...           ...  ...           ...
# 1995  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1996  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1997  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1998  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
# 1999  1.354578e-18  0.000000  0.000000  9.532912e-19  ...  6.851828e-19
#
#              f_780     f_840         f_900     f_960    f_1020        f_1080  \
# 0     2.804903e-03  0.000000  1.115797e-03  0.000541  0.001074  4.129106e-04
# 1     3.827063e-03  0.000757  1.827950e-03  0.000924  0.002003  1.353241e-03
# 2     2.196979e-03  0.001957  8.566290e-04  0.001364  0.001421  0.000000e+00
# 3     2.725649e-03  0.000000  1.712378e-03  0.001216  0.001194  8.769052e-04
# 4     2.994829e-03  0.000000  1.151151e-03  0.000000  0.001070  0.000000e+00
# ...            ...       ...           ...       ...       ...           ...
# 1995  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1996  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1997  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1998  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
# 1999  6.252813e-19  0.000000  7.212127e-19  0.000000  0.000000  6.643400e-19
#
#         f_1140        f_1200     device
# 0     0.000979  7.242021e-04  microwave
# 1     0.000000  1.370588e-03  microwave
# 2     0.001726  0.000000e+00  microwave
# 3     0.001102  1.548668e-03  microwave
# 4     0.001244  7.511724e-04  microwave
# ...        ...           ...        ...
# 1995  0.000000  5.289863e-19        fan
# 1996  0.000000  5.289863e-19        fan
# 1997  0.000000  5.289863e-19        fan
# 1998  0.000000  5.289863e-19        fan
# 1999  0.000000  5.289863e-19        fan
#
# [2000 rows x 21 columns]

# %%
classes = ["microwave", "airConditioner", "refrigerator", "monitor", "fan"]
X = df.drop(columns=['device'])
y = df['device'].apply(classes.index).to_numpy()
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)

# %% [markdown]
# ## MLP

# %%
GRID = [
    {'scaler': [StandardScaler()],
     'estimator': [MLPClassifier(random_state=42)],
     'estimator__hidden_layer_sizes': [(500, 400, 300, 200, 100), (400, 400, 400, 400, 400), (300, 300, 300, 300, 300), (200, 200, 200, 200, 200)],
     'estimator__activation': ['logistic', 'tanh', 'relu']
     }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', MLPClassifier())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  40.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  25.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  44.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  38.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  33.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  23.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  25.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  24.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  36.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  27.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  38.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  41.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  29.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  28.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  32.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  31.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  43.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  27.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  41.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  18.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  17.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  30.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  30.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  31.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  22.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  18.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  23.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  33.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  24.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  14.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  17.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  16.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  12.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  15.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  10.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  14.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  15.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  15.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  13.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  30.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  13.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  23.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  27.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  21.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  22.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  16.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  18.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  29.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  40.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  26.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  32.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  38.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  18.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  35.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  38.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  26.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  27.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  19.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  25.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  28.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  21.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  13.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  16.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  15.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  34.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  16.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  12.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  16.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  22.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  17.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   9.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   9.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  15.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  15.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  12.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   9.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  20.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  15.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  14.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  10.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=   6.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=   8.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=   8.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  13.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  13.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=   7.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  11.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  15.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  15.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  25.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  26.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  26.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  26.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  13.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  13.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  27.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  13.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  23.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  11.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  14.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  12.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=   8.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  14.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  10.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  11.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  15.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=   7.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  12.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   4.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   6.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   5.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   9.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   5.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   5.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   4.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   8.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   7.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=   4.2s
# Melhor F1-SCORE:  0.9356917795576495
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a8440f97c1cc> in <cell line: 4>()
#       2 best_model = grid_search.fit(x_train, y_train)
#       3 print('Melhor F1-SCORE: ', best_model.best_score_)
# ----> 4 best = best_model.best_estimator_.get_params()['classifier']
#       5 best
#
# KeyError: 'classifier'

# %%
best_model.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('estimator',
#    MLPClassifier(hidden_layer_sizes=(400, 400, 400, 400, 400), random_state=42))],
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'estimator': MLPClassifier(hidden_layer_sizes=(400, 400, 400, 400, 400), random_state=42),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'estimator__activation': 'relu',
#  'estimator__alpha': 0.0001,
#  'estimator__batch_size': 'auto',
#  'estimator__beta_1': 0.9,
#  'estimator__beta_2': 0.999,
#  'estimator__early_stopping': False,
#  'estimator__epsilon': 1e-08,
#  'estimator__hidden_layer_sizes': (400, 400, 400, 400, 400),
#  'estimator__learning_rate': 'constant',
#  'estimator__learning_rate_init': 0.001,
#  'estimator__max_fun': 15000,
#  'estimator__max_iter': 200,
#  'estimator__momentum': 0.9,
#  'estimator__n_iter_no_change': 10,
#  'estimator__nesterovs_momentum': True,
#  'estimator__power_t': 0.5,
#  'estimator__random_state': 42,
#  'estimator__shuffle': True,
#  'estimator__solver': 'adam',
#  'estimator__tol': 0.0001,
#  'estimator__validation_fraction': 0.1,
#  'estimator__verbose': False,
#  'estimator__warm_start': False}

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.9456788869143914
# Acurácia:  0.94625

# %% [markdown]
# ## Perceptron

# %%
GRID = [
    {
        'scaler': [StandardScaler()],
        'estimator': [Perceptron(random_state=42)],
        'estimator__penalty': ['l1', 'l2', 'elasticnet'],
        'estimator__alpha': [0.0001, 0.001, 0.01, 0.1, 1.0],
        'estimator__max_iter': [100, 500, 1000],
     }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', Perceptron())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 45 candidates, totalling 450 fits
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# ...
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# Melhor F1-SCORE:  0.6599834993350491

# %%
best_model.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('estimator', Perceptron(max_iter=100, penalty='l1', random_state=42))],
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'estimator': Perceptron(max_iter=100, penalty='l1', random_state=42),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'estimator__alpha': 0.0001,
#  'estimator__class_weight': None,
#  'estimator__early_stopping': False,
#  'estimator__eta0': 1.0,
#  'estimator__fit_intercept': True,
#  'estimator__l1_ratio': 0.15,
#  'estimator__max_iter': 100,
#  'estimator__n_iter_no_change': 5,
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__shuffle': True,
#  'estimator__tol': 0.001,
#  'estimator__validation_fraction': 0.1,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False}

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.6826058239894117
# Acurácia:  0.69375
