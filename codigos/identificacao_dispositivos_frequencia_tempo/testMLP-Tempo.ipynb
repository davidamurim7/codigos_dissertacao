# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.graph_objs as go
from plotly import tools
from numpy.fft import fft, ifft
from scipy.signal import find_peaks
from scipy import signal
from scipy.signal import argrelextrema
py.init_notebook_mode(connected=True)
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
#from catboost import CatBoostClassifier
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('/content/drive/MyDrive/PCOMP/dataSetPCOMP_time.csv')
df
# Out:
#             t_1        t_2        t_3        t_4        t_5        t_6  \
# 0       -0.0072    -0.0064    -0.0088    -0.0072    -0.0072    -0.0064
# 1       -8.0000    -8.0000    -8.0000    -0.0104    -0.0072    -0.0064
# 2       -8.0000    -0.0072    -0.0088    -0.0072    -8.0000    -8.0000
# 3       -0.0056    -0.0056    -8.0000    -0.0088    -8.0000    -8.0000
# 4       -4.0000    -0.0056    -0.0064    -0.0064    -8.0000    -0.0088
# ...         ...        ...        ...        ...        ...        ...
# 4995  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000
# 4996  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000   936.0000
# 4997    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000
# 4998    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000
# 4999  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000
#
#             t_7        t_8        t_9       t_10  ...       t_32       t_33  \
# 0       -0.0048    -0.0032    -0.0024     0.0024  ...     0.0016     0.0008
# 1       -0.0064    -0.0048    -0.0032    -0.0024  ...     4.0000     0.0024
# 2       -0.0072    -0.0064    -0.0064    -4.0000  ...     0.0056     0.0048
# 3       -8.0000    -0.0096    -0.0064    -0.0064  ...     0.0088     0.0072
# 4       -0.0088    -8.0000    -8.0000    -0.0072  ...    12.0000     0.0096
# ...         ...        ...        ...        ...  ...        ...        ...
# 4995  1016.0000  1016.0000  1016.0000  1016.0000  ...  1016.0000  1016.0000
# 4996   752.0000   568.0000   352.0000   192.0000  ...    -1.0000    -1.0000
# 4997    -1.0000    -1.0000    -1.0000    -1.0000  ...    -1.0000    -1.0000
# 4998    -1.0000    -1.0000    -1.0000    -1.0000  ...  1016.0000  1016.0000
# 4999  1016.0000  1016.0000  1016.0000  1016.0000  ...  1016.0000  1016.0000
#
#            t_34       t_35       t_36       t_37       t_38       t_39  \
# 0       -0.0008    -0.0032    -0.0032    -0.0048    -0.0064    -0.0064
# 1        0.0008    -0.0016    -0.0016    -0.0032    -4.0000    -0.0056
# 2        0.0016     0.0024     0.0008     0.0000    -0.0016    -0.0032
# 3        0.0056     0.0048     0.0032     0.0024    -0.0008    -0.0032
# 4        8.0000     0.0072     0.0088     4.0000     0.0024     0.0008
# ...         ...        ...        ...        ...        ...        ...
# 4995  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000
# 4996    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000
# 4997    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000    -1.0000
# 4998  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000
# 4999  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000  1016.0000
#
#            t_40          device
# 0       -0.0096             fan
# 1       -0.0064             fan
# 2       -0.0048             fan
# 3       -0.0032             fan
# 4       -0.0008             fan
# ...         ...             ...
# 4995  1016.0000  airConditioner
# 4996    -1.0000  airConditioner
# 4997    -1.0000  airConditioner
# 4998  1016.0000  airConditioner
# 4999  1016.0000  airConditioner
#
# [5000 rows x 41 columns]

# %%
classes = ["microwave", "airConditioner", "refrigerator", "monitor", "fan"]
X = df.drop(columns=['device'])
y = df['device'].apply(classes.index).to_numpy()
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)

# %%
GRID = [
    {'scaler': [StandardScaler()],
     'estimator': [MLPClassifier(random_state=42)],
     'estimator__hidden_layer_sizes': [(500, 400, 300, 200, 100), (400, 400, 400, 400, 400), (300, 300, 300, 300, 300), (200, 200, 200, 200, 200)],
     'estimator__activation': ['logistic', 'tanh', 'relu']
     }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', MLPClassifier())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  49.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  41.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  51.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  42.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  57.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  35.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  52.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  46.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  40.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.5min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.0min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  30.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  49.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  39.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  57.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.7min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.1min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.5min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.5min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  44.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  57.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  56.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  58.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  56.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  49.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  57.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  59.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  57.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=logistic, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  53.7s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  48.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 2.1min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 2.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 2.7min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.8min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  30.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.8min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 3.0min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 2.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 2.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  58.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.7min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.9min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 3.9min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 2.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  52.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.7min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.9min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  58.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  40.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  42.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  53.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time= 1.5min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  55.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  51.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time= 1.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  30.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time= 1.1min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time= 1.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  24.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=tanh, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  54.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  51.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.3min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  40.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  38.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time= 1.1min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  34.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  43.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  54.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(500, 400, 300, 200, 100), scaler=StandardScaler(); total time=  55.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  53.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.8min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.6min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.9min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.9min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time= 1.4min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  57.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(400, 400, 400, 400, 400), scaler=StandardScaler(); total time=  51.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  33.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  56.8s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.1min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  31.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  15.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  14.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time= 1.2min
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  32.4s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  15.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(300, 300, 300, 300, 300), scaler=StandardScaler(); total time=  43.9s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  31.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  20.3s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  47.1s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  21.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  34.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  23.6s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  23.5s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  19.2s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  42.0s
# [CV] END estimator=MLPClassifier(random_state=42), estimator__activation=relu, estimator__hidden_layer_sizes=(200, 200, 200, 200, 200), scaler=StandardScaler(); total time=  18.6s
# Melhor F1-SCORE:  0.8098392478700962

# %%
best_model.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('estimator',
#    MLPClassifier(hidden_layer_sizes=(400, 400, 400, 400, 400), random_state=42))],
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'estimator': MLPClassifier(hidden_layer_sizes=(400, 400, 400, 400, 400), random_state=42),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'estimator__activation': 'relu',
#  'estimator__alpha': 0.0001,
#  'estimator__batch_size': 'auto',
#  'estimator__beta_1': 0.9,
#  'estimator__beta_2': 0.999,
#  'estimator__early_stopping': False,
#  'estimator__epsilon': 1e-08,
#  'estimator__hidden_layer_sizes': (400, 400, 400, 400, 400),
#  'estimator__learning_rate': 'constant',
#  'estimator__learning_rate_init': 0.001,
#  'estimator__max_fun': 15000,
#  'estimator__max_iter': 200,
#  'estimator__momentum': 0.9,
#  'estimator__n_iter_no_change': 10,
#  'estimator__nesterovs_momentum': True,
#  'estimator__power_t': 0.5,
#  'estimator__random_state': 42,
#  'estimator__shuffle': True,
#  'estimator__solver': 'adam',
#  'estimator__tol': 0.0001,
#  'estimator__validation_fraction': 0.1,
#  'estimator__verbose': False,
#  'estimator__warm_start': False}

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.7802399806475291
# Acurácia:  0.787

# %% [markdown]
# ## Perceptron

# %%
GRID = [
    {
        'scaler': [StandardScaler()],
        'estimator': [Perceptron(random_state=42)],
        'estimator__penalty': ['l1', 'l2', 'elasticnet'],
        'estimator__alpha': [0.0001, 0.001, 0.01, 0.1, 1.0],
        'estimator__max_iter': [100, 500, 1000],
     }
]

PIPELINE = Pipeline([('scaler', None), ('estimator', Perceptron())])

# %%
grid_search = GridSearchCV(estimator=PIPELINE, param_grid=GRID, scoring="f1_macro", cv=10, verbose=2)
best_model = grid_search.fit(x_train, y_train)
print('Melhor F1-SCORE: ', best_model.best_score_)
# Out:
# Fitting 10 folds for each of 45 candidates, totalling 450 fits
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.2s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.0001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.001, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.01, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# ...
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.1s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=0.1, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=100, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=500, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l1, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=l2, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# [CV] END estimator=Perceptron(random_state=42), estimator__alpha=1.0, estimator__max_iter=1000, estimator__penalty=elasticnet, scaler=StandardScaler(); total time=   0.0s
# Melhor F1-SCORE:  0.148527755427834

# %%
best_model.best_estimator_.get_params()

# %%
best_return = best_model.predict(x_test)
print("F1-Score: ",f1_score(y_test, best_return, average='macro'))
print("Acurácia: ", accuracy_score(y_test,best_return))
# Out:
# F1-Score:  0.06666666666666668
# Acurácia:  0.2
# F1-Score:  0.06666666666666668
# Acurácia:  0.2
